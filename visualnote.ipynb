# %%
import pandas as pd
import os
import numpy as np



all_datasets_accuracies = {'arabic-letters-900-images-per-letter': {'model_imagesPerEntity_918_imgSize_16': 0.273, 'model_imagesPerEntity_918_imgSize_32': 0.681, 'model_imagesPerEntity_918_imgSize_64': 0.904, 'model_imagesPerEntity_918_imgSize_128': 0.719, 'model_imagesPerEntity_918_imgSize_256': 0.586, 'model_imagesPerEntity_918_imgSize_300': 0.09, 'model_imagesPerEntity_1048_imgSize_16': 0.216, 'model_imagesPerEntity_1048_imgSize_32': 0.477, 'model_imagesPerEntity_1048_imgSize_64': 0.641, 'model_imagesPerEntity_1048_imgSize_128': 0.474, 'model_imagesPerEntity_1048_imgSize_256': 0.223, 'model_imagesPerEntity_1048_imgSize_300': 0.471, 'model_imagesPerEntity_2481_imgSize_16': 0.076, 'model_imagesPerEntity_2481_imgSize_32': 0.104, 'model_imagesPerEntity_2481_imgSize_64': 0.079, 'model_imagesPerEntity_2481_imgSize_128': 0.104, 'model_imagesPerEntity_2481_imgSize_256': 0.091, 'model_imagesPerEntity_2481_imgSize_300': 0.077}, 'arabic-letters-1000-images-per-letter': {'model_imagesPerEntity_918_imgSize_16': 0.255, 'model_imagesPerEntity_918_imgSize_32': 0.428, 'model_imagesPerEntity_918_imgSize_64': 0.496, 'model_imagesPerEntity_918_imgSize_128': 0.259, 'model_imagesPerEntity_918_imgSize_256': 0.18, 'model_imagesPerEntity_918_imgSize_300': 0.088, 'model_imagesPerEntity_1048_imgSize_16': 0.698, 'model_imagesPerEntity_1048_imgSize_32': 0.782, 'model_imagesPerEntity_1048_imgSize_64': 0.933, 'model_imagesPerEntity_1048_imgSize_128': 0.802, 'model_imagesPerEntity_1048_imgSize_256': 0.555, 'model_imagesPerEntity_1048_imgSize_300': 0.898, 'model_imagesPerEntity_2481_imgSize_16': 0.169, 'model_imagesPerEntity_2481_imgSize_32': 0.183, 'model_imagesPerEntity_2481_imgSize_64': 0.199, 'model_imagesPerEntity_2481_imgSize_128': 0.171, 'model_imagesPerEntity_2481_imgSize_256': 0.137, 'model_imagesPerEntity_2481_imgSize_300': 0.093}, 'clean-2500-letters-only': {'model_imagesPerEntity_918_imgSize_16': 0.178, 'model_imagesPerEntity_918_imgSize_32': 0.274, 'model_imagesPerEntity_918_imgSize_64': 0.222, 'model_imagesPerEntity_918_imgSize_128': 0.083, 'model_imagesPerEntity_918_imgSize_256': 0.068, 'model_imagesPerEntity_918_imgSize_300': 0.071, 'model_imagesPerEntity_1048_imgSize_16': 0.279, 'model_imagesPerEntity_1048_imgSize_32': 0.327, 'model_imagesPerEntity_1048_imgSize_64': 0.388, 'model_imagesPerEntity_1048_imgSize_128': 0.234, 'model_imagesPerEntity_1048_imgSize_256': 0.064, 'model_imagesPerEntity_1048_imgSize_300': 0.122, 'model_imagesPerEntity_2481_imgSize_16': 0.975, 'model_imagesPerEntity_2481_imgSize_32': 0.981, 'model_imagesPerEntity_2481_imgSize_64': 0.999, 'model_imagesPerEntity_2481_imgSize_128': 0.999, 'model_imagesPerEntity_2481_imgSize_256': 0.998, 'model_imagesPerEntity_2481_imgSize_300': 0.979}}


accuracies_df = pd.DataFrame(all_datasets_accuracies).T
# transpose if needed
if accuracies_df.shape[1] > accuracies_df.shape[0]:
    accuracies_df = accuracies_df.transpose()
accuracies_df = accuracies_df.style.background_gradient(cmap='tab20_r').set_table_styles([dict(selector="th", props=[("text-align", "center")])])
display(accuracies_df)
# Out:
# <style type="text/css">
# #T_6d1e9 th {
#   text-align: center;
# }
# #T_6d1e9_row0_col0, #T_6d1e9_row1_col2, #T_6d1e9_row3_col1, #T_6d1e9_row6_col2 {
#   background-color: #c7c7c7;
#   color: #000000;
# }
# #T_6d1e9_row0_col1, #T_6d1e9_row2_col2, #T_6d1e9_row6_col0, #T_6d1e9_row9_col2, #T_6d1e9_row10_col0 {
#   background-color: #bcbd22;
#   color: #000000;
# }
# #T_6d1e9_row0_col2, #T_6d1e9_row4_col1, #T_6d1e9_row13_col1, #T_6d1e9_row14_col1 {
#   background-color: #dbdb8d;
#   color: #000000;
# }
# #T_6d1e9_row1_col0, #T_6d1e9_row6_col1 {
#   background-color: #98df8a;
#   color: #000000;
# }
# #T_6d1e9_row1_col1 {
#   background-color: #c49c94;
#   color: #f1f1f1;
# }
# #T_6d1e9_row2_col0, #T_6d1e9_row8_col1, #T_6d1e9_row11_col1, #T_6d1e9_row12_col2, #T_6d1e9_row13_col2, #T_6d1e9_row14_col2, #T_6d1e9_row15_col2, #T_6d1e9_row16_col2, #T_6d1e9_row17_col2 {
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_6d1e9_row2_col1, #T_6d1e9_row7_col0, #T_6d1e9_row9_col0, #T_6d1e9_row11_col0 {
#   background-color: #8c564b;
#   color: #f1f1f1;
# }
# #T_6d1e9_row3_col0 {
#   background-color: #2ca02c;
#   color: #f1f1f1;
# }
# #T_6d1e9_row3_col2, #T_6d1e9_row4_col2, #T_6d1e9_row5_col0, #T_6d1e9_row5_col1, #T_6d1e9_row5_col2, #T_6d1e9_row10_col2, #T_6d1e9_row12_col0, #T_6d1e9_row13_col0, #T_6d1e9_row14_col0, #T_6d1e9_row15_col0, #T_6d1e9_row16_col0, #T_6d1e9_row17_col0, #T_6d1e9_row17_col1 {
#   background-color: #9edae5;
#   color: #000000;
# }
# #T_6d1e9_row4_col0 {
#   background-color: #ff9896;
#   color: #000000;
# }
# #T_6d1e9_row7_col1, #T_6d1e9_row9_col1 {
#   background-color: #ffbb78;
#   color: #000000;
# }
# #T_6d1e9_row7_col2 {
#   background-color: #7f7f7f;
#   color: #f1f1f1;
# }
# #T_6d1e9_row8_col0 {
#   background-color: #d62728;
#   color: #f1f1f1;
# }
# #T_6d1e9_row8_col2 {
#   background-color: #f7b6d2;
#   color: #000000;
# }
# #T_6d1e9_row10_col1 {
#   background-color: #9467bd;
#   color: #f1f1f1;
# }
# #T_6d1e9_row11_col2, #T_6d1e9_row12_col1, #T_6d1e9_row15_col1, #T_6d1e9_row16_col1 {
#   background-color: #17becf;
#   color: #000000;
# }
# </style>
# <table id="T_6d1e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d1e9_level0_col0" class="col_heading level0 col0" >arabic-letters-900-images-per-letter</th>
#       <th id="T_6d1e9_level0_col1" class="col_heading level0 col1" >arabic-letters-1000-images-per-letter</th>
#       <th id="T_6d1e9_level0_col2" class="col_heading level0 col2" >clean-2500-letters-only</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d1e9_level0_row0" class="row_heading level0 row0" >model_imagesPerEntity_918_imgSize_16</th>
#       <td id="T_6d1e9_row0_col0" class="data row0 col0" >0.273000</td>
#       <td id="T_6d1e9_row0_col1" class="data row0 col1" >0.255000</td>
#       <td id="T_6d1e9_row0_col2" class="data row0 col2" >0.178000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row1" class="row_heading level0 row1" >model_imagesPerEntity_918_imgSize_32</th>
#       <td id="T_6d1e9_row1_col0" class="data row1 col0" >0.681000</td>
#       <td id="T_6d1e9_row1_col1" class="data row1 col1" >0.428000</td>
#       <td id="T_6d1e9_row1_col2" class="data row1 col2" >0.274000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row2" class="row_heading level0 row2" >model_imagesPerEntity_918_imgSize_64</th>
#       <td id="T_6d1e9_row2_col0" class="data row2 col0" >0.904000</td>
#       <td id="T_6d1e9_row2_col1" class="data row2 col1" >0.496000</td>
#       <td id="T_6d1e9_row2_col2" class="data row2 col2" >0.222000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row3" class="row_heading level0 row3" >model_imagesPerEntity_918_imgSize_128</th>
#       <td id="T_6d1e9_row3_col0" class="data row3 col0" >0.719000</td>
#       <td id="T_6d1e9_row3_col1" class="data row3 col1" >0.259000</td>
#       <td id="T_6d1e9_row3_col2" class="data row3 col2" >0.083000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row4" class="row_heading level0 row4" >model_imagesPerEntity_918_imgSize_256</th>
#       <td id="T_6d1e9_row4_col0" class="data row4 col0" >0.586000</td>
#       <td id="T_6d1e9_row4_col1" class="data row4 col1" >0.180000</td>
#       <td id="T_6d1e9_row4_col2" class="data row4 col2" >0.068000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row5" class="row_heading level0 row5" >model_imagesPerEntity_918_imgSize_300</th>
#       <td id="T_6d1e9_row5_col0" class="data row5 col0" >0.090000</td>
#       <td id="T_6d1e9_row5_col1" class="data row5 col1" >0.088000</td>
#       <td id="T_6d1e9_row5_col2" class="data row5 col2" >0.071000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row6" class="row_heading level0 row6" >model_imagesPerEntity_1048_imgSize_16</th>
#       <td id="T_6d1e9_row6_col0" class="data row6 col0" >0.216000</td>
#       <td id="T_6d1e9_row6_col1" class="data row6 col1" >0.698000</td>
#       <td id="T_6d1e9_row6_col2" class="data row6 col2" >0.279000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row7" class="row_heading level0 row7" >model_imagesPerEntity_1048_imgSize_32</th>
#       <td id="T_6d1e9_row7_col0" class="data row7 col0" >0.477000</td>
#       <td id="T_6d1e9_row7_col1" class="data row7 col1" >0.782000</td>
#       <td id="T_6d1e9_row7_col2" class="data row7 col2" >0.327000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row8" class="row_heading level0 row8" >model_imagesPerEntity_1048_imgSize_64</th>
#       <td id="T_6d1e9_row8_col0" class="data row8 col0" >0.641000</td>
#       <td id="T_6d1e9_row8_col1" class="data row8 col1" >0.933000</td>
#       <td id="T_6d1e9_row8_col2" class="data row8 col2" >0.388000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row9" class="row_heading level0 row9" >model_imagesPerEntity_1048_imgSize_128</th>
#       <td id="T_6d1e9_row9_col0" class="data row9 col0" >0.474000</td>
#       <td id="T_6d1e9_row9_col1" class="data row9 col1" >0.802000</td>
#       <td id="T_6d1e9_row9_col2" class="data row9 col2" >0.234000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row10" class="row_heading level0 row10" >model_imagesPerEntity_1048_imgSize_256</th>
#       <td id="T_6d1e9_row10_col0" class="data row10 col0" >0.223000</td>
#       <td id="T_6d1e9_row10_col1" class="data row10 col1" >0.555000</td>
#       <td id="T_6d1e9_row10_col2" class="data row10 col2" >0.064000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row11" class="row_heading level0 row11" >model_imagesPerEntity_1048_imgSize_300</th>
#       <td id="T_6d1e9_row11_col0" class="data row11 col0" >0.471000</td>
#       <td id="T_6d1e9_row11_col1" class="data row11 col1" >0.898000</td>
#       <td id="T_6d1e9_row11_col2" class="data row11 col2" >0.122000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row12" class="row_heading level0 row12" >model_imagesPerEntity_2481_imgSize_16</th>
#       <td id="T_6d1e9_row12_col0" class="data row12 col0" >0.076000</td>
#       <td id="T_6d1e9_row12_col1" class="data row12 col1" >0.169000</td>
#       <td id="T_6d1e9_row12_col2" class="data row12 col2" >0.975000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row13" class="row_heading level0 row13" >model_imagesPerEntity_2481_imgSize_32</th>
#       <td id="T_6d1e9_row13_col0" class="data row13 col0" >0.104000</td>
#       <td id="T_6d1e9_row13_col1" class="data row13 col1" >0.183000</td>
#       <td id="T_6d1e9_row13_col2" class="data row13 col2" >0.981000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row14" class="row_heading level0 row14" >model_imagesPerEntity_2481_imgSize_64</th>
#       <td id="T_6d1e9_row14_col0" class="data row14 col0" >0.079000</td>
#       <td id="T_6d1e9_row14_col1" class="data row14 col1" >0.199000</td>
#       <td id="T_6d1e9_row14_col2" class="data row14 col2" >0.999000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row15" class="row_heading level0 row15" >model_imagesPerEntity_2481_imgSize_128</th>
#       <td id="T_6d1e9_row15_col0" class="data row15 col0" >0.104000</td>
#       <td id="T_6d1e9_row15_col1" class="data row15 col1" >0.171000</td>
#       <td id="T_6d1e9_row15_col2" class="data row15 col2" >0.999000</td>
#     </tr>
#     <tr>
#       <th id="T_6d1e9_level0_row16" class="row
